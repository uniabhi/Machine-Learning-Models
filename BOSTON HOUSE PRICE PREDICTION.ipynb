# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
bos = pd.DataFrame(boston.data, columns=boston.feature_names)

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(bos[bos.CHAS==0])
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
bos['House_price'] = boston.target

# %%
bos.sort_values('House_price',ascending=False)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 283   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850   1.0  198.0
# 225   0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944   8.0  307.0
# 369   5.66998   0.0  18.10   1.0  0.631  6.683   96.8  1.3567  24.0  666.0
# 370   6.53876   0.0  18.10   1.0  0.631  7.016   97.5  1.2024  24.0  666.0
# 371   9.23230   0.0  18.10   0.0  0.631  6.216  100.0  1.1691  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 414  45.74610   0.0  18.10   0.0  0.693  4.519  100.0  1.6582  24.0  666.0
# 399   9.91655   0.0  18.10   0.0  0.693  5.852   77.8  1.5004  24.0  666.0
# 400  25.04610   0.0  18.10   0.0  0.693  5.987  100.0  1.5888  24.0  666.0
# 398  38.35180   0.0  18.10   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 405  67.92080   0.0  18.10   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
#
#      PTRATIO       B  LSTAT  House_price
# ...

# %%
bos=bos[bos.House_price!=50]

# %%
bos.isnull().sum()
# Out:
# CRIM           0
# ZN             0
# INDUS          0
# CHAS           0
# NOX            0
# RM             0
# AGE            0
# DIS            0
# RAD            0
# TAX            0
# PTRATIO        0
# B              0
# LSTAT          0
# House_price    0
# dtype: int64

# %%
bos[bos.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, House_price]
# Index: []

# %%
bos.shape
# Out:
# (490, 14)

# %%
bos.dtypes
# Out:
# CRIM           float64
# ZN             float64
# INDUS          float64
# CHAS           float64
# NOX            float64
# RM             float64
# AGE            float64
# DIS            float64
# RAD            float64
# TAX            float64
# PTRATIO        float64
# B              float64
# LSTAT          float64
# House_price    float64
# dtype: object

# %%
bos.nunique()
# Out:
# CRIM           489
# ZN              26
# INDUS           74
# CHAS             2
# NOX             80
# RM             431
# AGE            350
# DIS            398
# RAD              9
# TAX             64
# PTRATIO         44
# B              342
# LSTAT          442
# House_price    228
# dtype: int64

# %%
correlation_matrix = bos.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
z = np.abs(stats.zscore(bos))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 55,  56,  57,  65,  66, 102, 141, 142, 152, 154, 155, 160, 190,
#        191, 192, 193, 194, 195, 196, 197, 197, 201, 202, 203, 204, 205,
#        209, 211, 212, 213, 214, 215, 217, 220, 224, 225, 225, 226, 228,
#        245, 246, 247, 248, 253, 253, 259, 263, 264, 266, 267, 270, 272,
#        272, 273, 275, 279, 280, 281, 336, 337, 340, 341, 342, 342, 343,
#        343, 344, 344, 345, 346, 347, 352, 353, 353, 354, 356, 357, 358,
#        358, 364, 382, 388, 389, 390, 394, 394, 395, 396, 396, 398, 398,
#        399, 400, 402, 402, 403, 407, 408, 409, 410, 411, 411, 413, 420,
#        421, 422, 429, 434, 438, 439, 440, 441, 450], dtype=int64), array([ 1,  1,  1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  1,  1, 13,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5, 13,
#         5,  5, 13,  3,  3,  5,  1,  1,  1,  5, 13,  3,  3,  3,  3,  3, 13,
#         3, 13,  1,  1,  1,  1,  1,  1,  1,  7,  7,  1,  7,  1,  7,  1,  7,
# ...

# %%
bos.shape
# Out:
# (490, 14)

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  490.000000  490.000000  490.000000  490.000000  490.000000  490.000000
# mean     3.643241   11.112245   11.113143    0.059184    0.554307    6.245471
# std      8.722154   22.844626    6.821302    0.236209    0.116688    0.653147
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.881000
# 50%      0.247510    0.000000    9.690000    0.000000    0.538000    6.185000
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.578000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#              AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  490.00000  490.000000  490.000000  490.000000  490.000000  490.000000
# mean    68.27898    3.834519    9.514286  408.002041   18.520000  355.855449
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(bos['House_price'], bins=30)
plt.show()
# Out:
# C:\Users\goodluck\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
correlation_matrix = bos.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
X = pd.DataFrame(np.c_[bos['LSTAT'], bos['RM'],bos['PTRATIO'],bos['INDUS']], columns = ['LSTAT','RM','PTRATIO','INDUS'])
Y = bos['House_price']
print(X)
print(Y)
# Out:
#      LSTAT     RM  PTRATIO  INDUS
# 0     4.98  6.575     15.3   2.31
# 1     9.14  6.421     17.8   7.07
# 2     4.03  7.185     17.8   7.07
# 3     2.94  6.998     18.7   2.18
# 4     5.33  7.147     18.7   2.18
# ..     ...    ...      ...    ...
# 485   9.67  6.593     21.0  11.93
# 486   9.08  6.120     21.0  11.93
# 487   5.64  6.976     21.0  11.93
# 488   6.48  6.794     21.0  11.93
# 489   7.88  6.030     21.0  11.93
#
# [490 rows x 4 columns]
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: House_price, Length: 490, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (343, 4)
# (147, 4)
# (343,)
# (147,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()

# %%
from sklearn import model_selection
import math

print("Root Mean Square Error (RMSE) score\n")
scoring = 'neg_mean_squared_error'
kfold = model_selection.KFold(n_splits=10, random_state=6, shuffle = True)
cv = model_selection.cross_val_score(lin_model, X_train, y_train, cv=kfold, scoring=scoring)
sqrt_cv = [math.sqrt(abs(i)) for i in cv]
print("{} ({})".format( np.mean(sqrt_cv), np.std(sqrt_cv)))
print('Result from each iteration of cross validation:', cv, '\n')
# Out:
# Root Mean Square Error (RMSE) score
#
# 4.409255932580011 (0.6036045690005332)
# Result from each iteration of cross validation: [-25.8050061  -18.3405443  -15.22813054 -12.79984554 -20.13079071
#  -14.59743764 -28.52452026 -13.94051216 -24.62354824 -24.06842805]

# %%
print("R-squared Value\n")
scoring = 'r2'
kfold = model_selection.KFold(n_splits=10, random_state=6,shuffle=True)
cv = model_selection.cross_val_score(lin_model, X_train, y_train, cv=kfold, scoring=scoring)
print("{} ({})".format( cv.mean(), cv.std()))
print('Result from each iteration of cross validation:', cv, '\n')
# Out:
# R-squared Value
#
# 0.6607356124721809 (0.1408248393254185)
# Result from each iteration of cross validation: [0.62460761 0.69158063 0.71080581 0.61716701 0.80803596 0.73158792
#  0.2999232  0.80438751 0.74363354 0.57562694]

# %%
from sklearn.metrics import mean_squared_error, r2_score

model = lin_model
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

rmse_score = np.sqrt(mean_squared_error(y_test, y_pred))
rsquared_score = r2_score(y_test, y_pred)
print('RMSE score:', rmse_score)
print('R2 score:', rsquared_score)
print('\nScatter plot of y_test against y_pred:')
sns.regplot(y_test, y_pred);
# Out:
# RMSE score: 3.878950083964892
# R2 score: 0.7134464128074471
#
# Scatter plot of y_test against y_pred:
# C:\Users\goodluck\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
